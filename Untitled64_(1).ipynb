# %% [markdown]
# <a href="https://colab.research.google.com/github/arjun1829/Minor-project-verzeo/blob/main/Untitled64_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
from tensorflow.keras import datasets

# %%
(train_features,train_target),(test_features,test_target)=datasets.cifar10.load_data()

# %% [markdown]
# airplane-0 <br/>
# automobile-1<br/>
# bird-2<br/>
# cat-3<br/>
# deer-4<br/>
# dog-5<br/>
# frog-6<br/>
# horse-7<br/>
# ship-8<br/>
# truck-9<br/>

# %%
import matplotlib.pyplot as plt

# %%
for i in range(25):
  plt.imshow(train_features[i])

# %%
plt.figure(figsize=(10,10))
for i in range(25):
  plt.subplot(5,5,i+1)
  plt.imshow(train_features[i])
plt.show()

# %%
train_features.shape
# Out:
# (50000, 32, 32, 3)

# %%
train_features
# Out:
# array([[[[ 59,  62,  63],
#          [ 43,  46,  45],
#          [ 50,  48,  43],
#          ...,
#          [158, 132, 108],
#          [152, 125, 102],
#          [148, 124, 103]],
#
#         [[ 16,  20,  20],
#          [  0,   0,   0],
#          [ 18,   8,   0],
#          ...,
#          [123,  88,  55],
#          [119,  83,  50],
#          [122,  87,  57]],
#
#         [[ 25,  24,  21],
#          [ 16,   7,   0],
#          [ 49,  27,   8],
#          ...,
#          [118,  84,  50],
#          [120,  84,  50],
#          [109,  73,  42]],
#
#         ...,
#
#         [[208, 170,  96],
#          [201, 153,  34],
#          [198, 161,  26],
#          ...,
#          [160, 133,  70],
#          [ 56,  31,   7],
#          [ 53,  34,  20]],
#
#         [[180, 139,  96],
#          [173, 123,  42],
#          [186, 144,  30],
#          ...,
#          [184, 148,  94],
#          [ 97,  62,  34],
#          [ 83,  53,  34]],
#
#         [[177, 144, 116],
# ...

# %%
train_features=train_features/255

# %%
train_features.shape
# Out:
# (50000, 32, 32, 3)

# %%
train_features
# Out:
# array([[[[0.23137255, 0.24313725, 0.24705882],
#          [0.16862745, 0.18039216, 0.17647059],
#          [0.19607843, 0.18823529, 0.16862745],
#          ...,
#          [0.61960784, 0.51764706, 0.42352941],
#          [0.59607843, 0.49019608, 0.4       ],
#          [0.58039216, 0.48627451, 0.40392157]],
#
#         [[0.0627451 , 0.07843137, 0.07843137],
#          [0.        , 0.        , 0.        ],
#          [0.07058824, 0.03137255, 0.        ],
#          ...,
#          [0.48235294, 0.34509804, 0.21568627],
#          [0.46666667, 0.3254902 , 0.19607843],
#          [0.47843137, 0.34117647, 0.22352941]],
#
#         [[0.09803922, 0.09411765, 0.08235294],
#          [0.0627451 , 0.02745098, 0.        ],
#          [0.19215686, 0.10588235, 0.03137255],
#          ...,
#          [0.4627451 , 0.32941176, 0.19607843],
#          [0.47058824, 0.32941176, 0.19607843],
#          [0.42745098, 0.28627451, 0.16470588]],
#
#         ...,
#
# ...

# %%
from tensorflow.keras import models,layers

# %%
plt.figure(figsize=(10,10))
for i in range(25):
  plt.subplot(5,5,i+1)
  plt.imshow(train_features[i])
plt.show()

# %%
train_target.shape
# Out:
# (50000, 1)

# %%
model=models.Sequential()
model.add(layers.Conv2D(32,(3,3),activation="relu",input_shape=(32,32,3)))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(64,(3,3),activation="relu"))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(64,(3,3),activation="relu"))
model.add(layers.Flatten())
model.add(layers.Dense(64,activation="relu"))
model.add(layers.Dense(10))

# %%
model.compile(optimizer="adam",loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=["accuracy"])

# %%
model.fit(train_features,train_target,epochs=10)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 61s 39ms/step - loss: 1.7612 - accuracy: 0.3500
# Epoch 2/10
# 1563/1563 [==============================] - 61s 39ms/step - loss: 1.1737 - accuracy: 0.5828
# Epoch 3/10
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.9972 - accuracy: 0.6495
# Epoch 4/10
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.8721 - accuracy: 0.6929
# Epoch 5/10
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.8047 - accuracy: 0.7196
# Epoch 6/10
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.7422 - accuracy: 0.7396
# Epoch 7/10
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.6787 - accuracy: 0.7651
# Epoch 8/10
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.6272 - accuracy: 0.7808
# Epoch 9/10
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.5868 - accuracy: 0.7944
# Epoch 10/10
# ...

# %%
proability_model=tf.keras.Sequential([model,tf.keras.layers.Softmax()])

# %%
predictions=proability_model.predict(test_features)

# %%
predictions[0]
# Out:
# array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 1.1569974e-23, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00], dtype=float32)

# %%
import numpy as np

# %%
np.argmax(predictions[0])
# Out:
# 3

# %%
test_target[0]
# Out:
# array([3], dtype=uint8)
